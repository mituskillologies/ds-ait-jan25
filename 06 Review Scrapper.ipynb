# %%
import requests
from bs4 import BeautifulSoup

# Function to fetch reviews from a given URL
def fetch_reviews(url):
    # Send an HTTP GET request to the website
    response = requests.get(url)
    
    # If the request was successful (status code 200), parse the HTML content
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        text = soup.get_text(strip=False)
        return text
       
url = 'https://www.flipkart.com/portronics-sounddrum-1-10w-tws-portable-inbuilt-fm-type-c-charging-10-w-bluetooth-speaker/p/itm2e678c5363181'  # Replace with the actual URL of the product reviews page
text1 = fetch_reviews(url)

# %%
print(text1)
# Out:
#  Buy Portronics SoundDrum 1 10W TWS Portable, Inbuilt-FM & Type C Charging 10 W Bluetooth Speaker Online from Flipkart.com      Explore PlusLoginBecome a Seller More CartAdd to cart Buy NowHomeAudio & VideoSpeakersPortable AudioMobile SpeakersPortronics Mobile SpeakersPortronics SoundDrum 1 10W TWS Portable, Inbuilt-FM & Type C Charging 10 W Bluetooth Speaker (Blue, Mono Channel)
# ...

# %%
text1.split()
# Out:
# ['Buy',
#  'Portronics',
#  'SoundDrum',
#  '1',
#  '10W',
#  'TWS',
#  'Portable,',
#  'Inbuilt-FM',
#  '&',
#  'Type',
#  'C',
#  'Charging',
#  '10',
#  'W',
#  'Bluetooth',
#  'Speaker',
#  'Online',
#  'from',
#  'Flipkart.com',
#  'Explore',
#  'PlusLoginBecome',
#  'a',
#  'Seller',
#  'More',
#  'CartAdd',
#  'to',
#  'cart',
#  'Buy',
#  'NowHomeAudio',
#  '&',
#  'VideoSpeakersPortable',
#  'AudioMobile',
#  'SpeakersPortronics',
#  'Mobile',
#  'SpeakersPortronics',
#  'SoundDrum',
#  '1',
#  '10W',
#  'TWS',
#  'Portable,',
#  'Inbuilt-FM',
#  '&',
#  'Type',
#  'C',
#  'Charging',
#  '10',
#  'W',
#  'Bluetooth',
#  'Speaker',
#  '(Blue,',
#  'Mono',
#  'Channel)',
#  'CompareSharePortronics',
#  'SoundDrum',
#  '1',
#  '10W',
#  'TWS',
#  'Portable,',
#  'Inbuilt-FM',
#  '&',
#  'Type',
#  'C',
#  'Charging',
#  '10',
#  'W',
#  'Bluetooth',
#  'Speaker',
#  '(Blue,',
#  'Mono',
#  'Channel)4.376,021',
#  'Ratings',
#  '&',
#  '8,565',
#  'ReviewsSpecial',
# ...
