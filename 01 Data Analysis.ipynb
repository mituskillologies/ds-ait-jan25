# %%
import pandas as pd

# %%
s = pd.Series([34,22,76,54,17,48,64,27,89])

# %%
s
# Out:
# 0    34
# 1    22
# 2    76
# 3    54
# 4    17
# 5    48
# 6    64
# 7    27
# 8    89
# dtype: int64

# %%
s1 = pd.Series([34,22,76,54,17.89,48,64,27,89])
s1
# Out:
# 0    34.00
# 1    22.00
# 2    76.00
# 3    54.00
# 4    17.89
# 5    48.00
# 6    64.00
# 7    27.00
# 8    89.00
# dtype: float64

# %%
s.values
# Out:
# array([34, 22, 76, 54, 17, 48, 64, 27, 89])

# %%
r = pd.Series([1,2,3,4,5])
n = pd.Series(['ajay','asha','priya','rajan','nitin'])
m = pd.Series([56.78, 78.45, 76.90, 81.49, 63.25])

# %%
df = pd.DataFrame({
    'roll': r,
    'name': n,
    'marks': m
})

# %%
df
# Out:
#    roll   name  marks
# 0     1   ajay  56.78
# 1     2   asha  78.45
# 2     3  priya  76.90
# 3     4  rajan  81.49
# 4     5  nitin  63.25

# %%
# https://mitu.co.in/dataset
# Download all files where name starts with 'student' and save in 
# current working directory

# %%
import os
os.getcwd()
# Out:
# '/home/mitu/ait-jan25'

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df.shape
# Out:
# (10, 5)

# %%
df.size
# Out:
# 50

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
df1 = pd.read_csv('student1.csv')

# %%
df1
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
df1 = pd.read_csv('student1.csv', header=None)

# %%
df1
# Out:
#     0        1   2      3   4
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df1 = pd.read_csv('student1.csv', names=['A','B','C','D','E'])

# %%
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df3 = pd.read_csv('student3.tsv')

# %%
df3
# Out:
#   roll\tname\tclass\tmarks\tage
# 0        1\tanil\tTE\t56.77\t22
# 1        2\tamit\tTE\t59.77\t21
# 2      3\taniket\tBE\t76.88\t19
# 3     4\tajinkya\tTE\t69.66\t20
# 4        5\tasha\tTE\t63.28\t20
# 5      6\tayesha\tBE\t49.55\t20
# 6        7\tamar\tBE\t65.34\t19
# 7       8\tamita\tBE\t68.33\t23
# 8        9\tamol\tTE\t56.75\t20
# 9      10\tanmol\tBE\t78.66\t21

# %%
df3 = pd.read_csv('student3.tsv', sep = '\t')

# %%
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df.values.shape
# Out:
# (10, 5)

# %%
df.values.reshape(25,2)
# Out:
# array([[1, 'anil'],
#        ['TE', 56.77],
#        [22, 2],
#        ['amit', 'TE'],
#        [59.77, 21],
#        [3, 'aniket'],
#        ['BE', 76.88],
#        [19, 4],
#        ['ajinkya', 'TE'],
#        [69.66, 20],
#        [5, 'asha'],
#        ['TE', 63.28],
#        [20, 6],
#        ['ayesha', 'BE'],
#        [49.55, 20],
#        [7, 'amar'],
#        ['BE', 65.34],
#        [19, 8],
#        ['amita', 'BE'],
#        [68.33, 23],
#        [9, 'amol'],
#        ['TE', 56.75],
#        [20, 10],
#        ['anmol', 'BE'],
#        [78.66, 21]], dtype=object)

# %%
df.values.reshape(5,10)
# Out:
# array([[1, 'anil', 'TE', 56.77, 22, 2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19, 4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20, 6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19, 8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20, 10, 'anmol', 'BE', 78.66, 21]],
#       dtype=object)

# %%
x = df.iloc[2:9,1:4]
x
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75

# %%
df.iloc[:9,1:4]
# Out:
#       name class  marks
# 0     anil    TE  56.77
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75

# %%
df.iloc[2:,1:4]
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75
# 9    anmol    BE  78.66

# %%
df.iloc[2:9,1:]
# Out:
#       name class  marks  age
# 2   aniket    BE  76.88   19
# 3  ajinkya    TE  69.66   20
# 4     asha    TE  63.28   20
# 5   ayesha    BE  49.55   20
# 6     amar    BE  65.34   19
# 7    amita    BE  68.33   23
# 8     amol    TE  56.75   20

# %%
df.loc[2:9,'name']
# Out:
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[2:9,['name','marks']]
# Out:
#       name  marks
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df.loc[2:9,'roll':'marks']
# Out:
#    roll     name class  marks
# 2     3   aniket    BE  76.88
# 3     4  ajinkya    TE  69.66
# 4     5     asha    TE  63.28
# 5     6   ayesha    BE  49.55
# 6     7     amar    BE  65.34
# 7     8    amita    BE  68.33
# 8     9     amol    TE  56.75
# 9    10    anmol    BE  78.66

# %%
df.iloc[[4,7,6,8],:]
# Out:
#    roll   name class  marks  age
# 4     5   asha    TE  63.28   20
# 7     8  amita    BE  68.33   23
# 6     7   amar    BE  65.34   19
# 8     9   amol    TE  56.75   20

# %%
df.iloc[[4,7,6,8],[1,3]]
# Out:
#     name  marks
# 4   asha  63.28
# 7  amita  68.33
# 6   amar  65.34
# 8   amol  56.75

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.iloc[5,:]
# Out:
# roll          6
# name     ayesha
# class        BE
# marks     49.55
# age          20
# Name: 5, dtype: object

# %%
df.iloc[:,3]
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[[0,1,2,3,4,6,7,8,9],:]
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([5,2,7,8])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 9    10    anmol    BE  78.66   21

# %%
df.drop('class', axis = 1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df.drop(['class','age'], axis = 1)
# Out:
#    roll     name  marks
# 0     1     anil  56.77
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 5     6   ayesha  49.55
# 6     7     amar  65.34
# 7     8    amita  68.33
# 8     9     amol  56.75
# 9    10    anmol  78.66

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df['marks'].min()
# Out:
# 49.55

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df['marks'].median()
# Out:
# 64.31

# %%
df['marks'].sum()
# Out:
# 644.9899999999999

# %%
df['marks'].std()
# Out:
# 9.207178901994535

# %%
df['age'].mode()
# Out:
# 0    20
# Name: age, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
df.mean(numeric_only=True, axis=1)
# Out:
# 0    26.590000
# 1    27.590000
# 2    32.960000
# 3    31.220000
# 4    29.426667
# 5    25.183333
# 6    30.446667
# 7    33.110000
# 8    28.583333
# 9    36.553333
# dtype: float64

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['marks'] = df['marks'] + 0.5

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.27   22
# 1     2     amit    TE  60.27   21
# 2     3   aniket    BE  77.38   19
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 5     6   ayesha    BE  50.05   20
# 6     7     amar    BE  65.84   19
# 7     8    amita    BE  68.83   23
# 8     9     amol    TE  57.25   20
# 9    10    anmol    BE  79.16   21

# %%
df['cgpa'] = df['marks'] / 10 + 0.38

# %%
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  57.27   22  6.107
# 1     2     amit    TE  60.27   21  6.407
# 2     3   aniket    BE  77.38   19  8.118
# 3     4  ajinkya    TE  70.16   20  7.396
# 4     5     asha    TE  63.78   20  6.758
# 5     6   ayesha    BE  50.05   20  5.385
# 6     7     amar    BE  65.84   19  6.964
# 7     8    amita    BE  68.83   23  7.263
# 8     9     amol    TE  57.25   20  6.105
# 9    10    anmol    BE  79.16   21  8.296

# %%
x = ['M','M','M','M','F','F','M','F','M','M']

# %%
df['gender'] = x

# %%
df
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  57.27   22  6.107      M
# 1     2     amit    TE  60.27   21  6.407      M
# 2     3   aniket    BE  77.38   19  8.118      M
# 3     4  ajinkya    TE  70.16   20  7.396      M
# 4     5     asha    TE  63.78   20  6.758      F
# 5     6   ayesha    BE  50.05   20  5.385      F
# 6     7     amar    BE  65.84   19  6.964      M
# 7     8    amita    BE  68.83   23  7.263      F
# 8     9     amol    TE  57.25   20  6.105      M
# 9    10    anmol    BE  79.16   21  8.296      M

# %%
df = pd.read_csv('student.csv')

# %%
ndf = pd.DataFrame({
    'roll': range(1,11),
    'cgpa': df['marks'] / 10 + 0.38,
    'gender' : ['M','M','M','M','F','F','M','F','M','M']
})
ndf
# Out:
#    roll   cgpa gender
# 0     1  6.057      M
# 1     2  6.357      M
# 2     3  8.068      M
# 3     4  7.346      M
# 4     5  6.708      F
# 5     6  5.335      F
# 6     7  6.914      M
# 7     8  7.213      F
# 8     9  6.055      M
# 9    10  8.246      M

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'cgpa', 'gender'], dtype='object')

# %%
df.merge(ndf, on='roll')
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  56.77   22  6.057      M
# 1     2     amit    TE  59.77   21  6.357      M
# 2     3   aniket    BE  76.88   19  8.068      M
# 3     4  ajinkya    TE  69.66   20  7.346      M
# 4     5     asha    TE  63.28   20  6.708      F
# 5     6   ayesha    BE  49.55   20  5.335      F
# 6     7     amar    BE  65.34   19  6.914      M
# 7     8    amita    BE  68.33   23  7.213      F
# 8     9     amol    TE  56.75   20  6.055      M
# 9    10    anmol    BE  78.66   21  8.246      M

# %%
df5 = pd.read_csv('student5.csv')

# %%
df5
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df, df5], ignore_index=True)
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %%
df['marks'] > 60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask = df['marks'] > 60

# %%
df[mask]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['marks'] > 60]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[(df['marks'] > 60) & (df['class'] == 'BE')]
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df3 = pd.read_csv('student3.csv')

# %%
df3
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df3['age'].mean()
# Out:
# 20.785714285714285

# %%
df3['marks'].mean()

# %%
df3.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
df3.columns = df3.columns.str.strip()

# %%
df3['marks'].mean()
# Out:
# 66.96714285714286

# %%
df3['name'] = df3['name'].str.title()

# %%
df3
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    be  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df3['class'].value_counts()
# Out:
# class
# TE    9
# BE    4
# be    2
# Name: count, dtype: int64

# %%
df3['class'] = df3['class'].str.upper()

# %%
df3
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df3.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df3[df3.duplicated()]
# Out:
#    roll  name class  marks   age
# 9     9  Amol    TE  56.75  20.0

# %%
df3.drop_duplicates(inplace=True, ignore_index=True)

# %%
df3
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9     10    Anmol    BE  78.66   NaN
# 10    11   Surbhi    TE    NaN  23.0
# 11    12    Sujay    TE  74.12  22.0
# 12    13  Subhash    BE  88.45  21.0
# 13    14   Sachin   NaN  59.33  21.0
# 14    15  Shalini    TE  63.45  20.0

# %%
df3.count()
# Out:
# roll     15
# name     15
# class    14
# marks    13
# age      13
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    15 non-null     int64
#  1   name    15 non-null     object
#  2   class   14 non-null     object
#  3   marks   13 non-null     float64
#  4   age     13 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 728.0+ bytes

# %%
df3.isnull()
# Out:
#      roll   name  class  marks    age
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False   True
# 5   False  False  False   True  False
# 6   False  False  False  False  False
# 7   False  False  False  False  False
# 8   False  False  False  False  False
# 9   False  False  False  False   True
# 10  False  False  False   True  False
# 11  False  False  False  False  False
# 12  False  False  False  False  False
# 13  False  False   True  False  False
# 14  False  False  False  False  False

# %%
True + True
# Out:
# 2

# %%
df3.isnull().sum()
# Out:
# roll     0
# name     0
# class    1
# marks    2
# age      2
# dtype: int64

# %%
df.dropna()
# Out:
#    roll     name class  marks  age
# 0     1     Anil    TE  56.77   22
# 1     2     Amit    TE  59.77   21
# 2     3   Aniket    BE  76.88   19
# 3     4  Ajinkya    TE  69.66   20
# 4     5     Asha    TE  63.28   20
# 5     6   Ayesha    BE  49.55   20
# 6     7     Amar    BE  65.34   19
# 7     8    Amita    BE  68.33   23
# 8     9     Amol    TE  56.75   20
# 9    10    Anmol    BE  78.66   21

# %%
df3['age'].fillna(20)
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    23.0
# 11    22.0
# 12    21.0
# 13    21.0
# 14    20.0
# Name: age, dtype: float64

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     Anil    TE  56.77   22
# 1     2     Amit    TE  59.77   21
# 2     3   Aniket    BE  76.88   19
# 3     4  Ajinkya    TE  69.66   20
# 4     5     Asha    TE  63.28   20
# 5     6   Ayesha    BE  49.55   20
# 6     7     Amar    BE  65.34   19
# 7     8    Amita    BE  68.33   23
# 8     9     Amol    TE  56.75   20
# 9    10    Anmol    BE  78.66   21

# %%
df3
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9     10    Anmol    BE  78.66   NaN
# 10    11   Surbhi    TE    NaN  23.0
# 11    12    Sujay    TE  74.12  22.0
# 12    13  Subhash    BE  88.45  21.0
# 13    14   Sachin   NaN  59.33  21.0
# 14    15  Shalini    TE  63.45  20.0

# %%
df3['marks'].fillna(df3['marks'].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     67.753077
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 9     78.660000
# 10    67.753077
# 11    74.120000
# 12    88.450000
# 13    59.330000
# 14    63.450000
# Name: marks, dtype: float64

# %%
df3['age'].fillna(df3['age'].median())
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     21.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     21.0
# 10    23.0
# 11    22.0
# 12    21.0
# 13    21.0
# 14    20.0
# Name: age, dtype: float64

# %%
df3['class'].mode()[0]
# Out:
# 'TE'

# %%
df3['class'].fillna(df3['class'].mode()[0])
# Out:
# 0     TE
# 1     TE
# 2     BE
# 3     TE
# 4     TE
# 5     BE
# 6     BE
# 7     BE
# 8     TE
# 9     BE
# 10    TE
# 11    TE
# 12    BE
# 13    TE
# 14    TE
# Name: class, dtype: object

# %%
df3.ffill()
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  63.28  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9     10    Anmol    BE  78.66  20.0
# 10    11   Surbhi    TE  78.66  23.0
# 11    12    Sujay    TE  74.12  22.0
# 12    13  Subhash    BE  88.45  21.0
# 13    14   Sachin    BE  59.33  21.0
# 14    15  Shalini    TE  63.45  20.0

# %%
df3.bfill()
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  65.34  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9     10    Anmol    BE  78.66  23.0
# 10    11   Surbhi    TE  74.12  23.0
# 11    12    Sujay    TE  74.12  22.0
# 12    13  Subhash    BE  88.45  21.0
# 13    14   Sachin    TE  59.33  21.0
# 14    15  Shalini    TE  63.45  20.0

# %%
tdf = df3.bfill()

# %%
tdf.to_csv('finaldata.csv', index=False)

# %%
tdf.to_html('finaldata.html', index=False)
